# %% [markdown]
# # Compound design based on molecule set largest cluster
# # 07 基于公共骨架集的化合物设计
#
# ## 基础知识
#
# - 化合物设计是指利用化学信息和计算机算法来设计化合物，以满足特定化学需求或目标。
# - 化合物设计的关键是找到一种或多种化合物，其结构和活性都与目标化学需求相一致。
# - 化合物设计的过程包括：
#     - 化学信息收集：收集化学信息，包括结构、活性、化学特性、化学反应等。
#     - 化学空间建模：建立化学空间模型，包括结构、活性、化学特性、化学反应等。
#     - 化学优化：利用计算机算法进行化学优化，找到一种或多种化合物，其结构和活性都与目标化学需求相一致。
#     - 化学验证：验证设计的化合物是否满足目标化学需求。
# - 化合物设计的应用领域包括：
#     - 生物工程：用于制造具有特定功能或性能的化合物。
#     - 药物开发：用于开发具有特定药理效应的化合物。
#     - 生物制药：用于制造具有特定药理效应的化合物。
#     - 化学工程：用于开发具有特定化学特性的化合物。
#     - 材料科学：用于开发具有特定材料特性的化合物。
#     - 生物信息学：用于分析具有特定生物特性的化合物。
#
# ## 目标
#
# - 设计一种或多种化合物，其结构和活性都与目标化学需求相一致。
# - 设计的化合物应具有高的活性值和高的分子浓度。
# - 设计的化合物应具有高的分子浓度，且分子浓度应高于目标化学需求。
# - 设计的化合物应具有高的活性值，且活性值应高于目标化学需求。
# - 设计的化合物应具有高的分子浓度和高的活性值，且分子浓度和活性值应高于目标化学需求。
#
# ## 步骤
#
# 1. 收集化学信息：收集目标化学需求的化学信息，包括结构、活性、化学特性、化学反应等。
# 2. 建立化学空间模型：建立化学空间模型，包括结构、活性、化学特性、化学反应等。
# 3. 利用计算机算法进行化学优化：利用计算机算法进行化学优化，找到一种或多种化合物，其结构和活性都与目标化学需求相一致。
# 4. 验证设计的化合物是否满足目标化学需求：验证设计的化合物是否满足目标化学需求。
# 5. 优化设计的化合物：优化设计的化合物，使其具有高的分子浓度和高的活性值，且分子浓度和活性值应高于目标化学需求。
#
# ## 注意事项
#
# - 化合物设计的过程是一门科学，需要对化学知识、计算机算法、数学、物理等多门学科有一定的了解。
# - 化合物设计的结果可能是有效的，也可能是无效的。如果设计的化合物不满足目标化学需求，则需要重新设计。

# %% [markdown]
# ## 需要用到的知识
#
# - 化学信息收集：收集目标化学需求的化学信息，包括结构、活性、化学特性、化学反应等。
# - 化学空间建模：建立化学空间模型，包括结构、活性、化学特性、化学反应等。
# - 化学优化：利用计算机算法进行化学优化，找到一种或多种化合物，其结构和活性都与目标化学需求相一致。
# - 化学验证：验证设计的化合物是否满足目标化学需求。
# - 高分子浓度：分子浓度越高，分子越容易聚合，分子间的相互作用就越强。
# - 高活性值：活性值越高，化合物的活性就越强。
# - 目标化学需求：指的是化合物的结构、活性、化学特性、化学反应等。
#
# ## 药物结构优化与设计
#
# - 药物结构优化：通过改变药物的结构，来优化药物的分子浓度和活性值。
# - 药物结构设计：通过设计药物的结构，来优化药物的分子浓度和活性值。
# - 药物结构优化与设计的步骤：
#     - 收集药物结构优化与设计的目标化学需求。
#     - 建立药物结构优化与设计的化学空间模型。
#     - 利用计算机算法进行药物结构优化与设计。
#     - 验证药物结构优化与设计的化合物是否满足目标化学需求。
#     - 优化药物结构优化与设计的化合物，使其具有高的分子浓度和高的活性值。
#
# ## 化合物设计的步骤
# - 化合物设计的步骤：
#     - 收集化合物设计的目标化学需求。
#     - 建立化合物设计的化学空间模型。
#     - 利用计算机算法进行化合物设计。
#     - 验证设计的化合物是否满足目标化学需求。
#     - 优化设计的化合物，使其具有高的分子浓度和高的活性值。
#
# - 化合物优化的步骤：
#     - 收集化合物优化的目标化学需求。
#     - 建立化合物优化的化学空间模型。
#     - 利用计算机算法进行化合物优化。
#     - 验证优化的化合物是否满足目标化学需求。
#     - 优化优化的化合物，使其具有高的分子浓度和高的活性值。
# - Lipinski 规则：Lipinski 规则是一种常用的化学品质指标，它是由药物分析师 Lipinski 于 1997 年提出的。它规定了一种化合物的分子量、分子形状、分子摩尔质量、分子电荷、分子化学键、分子相互作用、分子相对分子体积。
# - 类先导三规则：类先导三规则是指一种化合物的分子量、分子形状、分子摩尔质量、分子电荷、分子化学键、分子相互作用、分子相对分子体积。
# - CSN药物分子量规则：CSN药物分子量规则是指一种化合物的分子量。
#     - CSN药物分子形状规则：CSN药物分子形状规则是指一种化合物的分子形状。
#     - CSN药物分子摩尔质量规则：CSN药物分子摩尔质量规则是指一种化合物的分子摩尔质量。
#     - CSN药物分子电荷规则：CSN药物分子电荷规则是指一种化合物的分子电荷。
#     - CSN药物分子化学键规则：CSN药物分子化学键规则是指一种化合物的分子化学键。
#     - CSN药物分子相互作用规则：CSN药物分子相互作用规则是指一种化合物的分子相互作用。
#     - CSN药物分子相对分子体积规则：CSN药物分子相对分子体积规则是指一种化合物的分子相对分子体积。
# - 脂水分布系数：脂水分布系数是指一种化合物中脂肪和水的比例。

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import rdFMCS

# %%
from pathlib import Path
import os

# 获取当前工作目录
HERE = Path(os.getcwd())
DATA = HERE / 'data'
if not DATA.exists():
    DATA.mkdir(parents=True, exist_ok=True)
print(DATA)
# Out:
# /Users/wangyang/Desktop/AIDD/07_Compound_design_based_on_molecule_set_largest_cluster/data

# %%
# Load the SDF file
sdf_file = str(HERE / "../05_Compound_clustering/data/molecule_set_largest_cluster.sdf")
supplier = Chem.SDMolSupplier(sdf_file)

# %% [markdown]
# # 1. 筛选有效分子

# %%
molecules = [mol for mol in supplier if mol is not None]

# %%
# 计算最大公共子结构( MCS )
mcs_result = rdFMCS.FindMCS(molecules)
mcs_smarts = mcs_result.smartsString
mcs_mol = Chem.MolFromSmarts(mcs_smarts)

# 将MCS转换为SMILES供参考
mcs_smiles = Chem.MolToSmiles(mcs_mol)
print("MCS SMILES:", mcs_smiles)

# 通过添加片段(例如,卤素、甲基等)对每个分子进行优化
optimized_smiles = []
for mol in molecules:
    # 创建可编辑的分子
    editable_mol = Chem.EditableMol(mol)
    
    # 添加一个示例优化，例如添加一个氯原子（Cl）和一个甲基（-CH3）⚠️：这里的添加氯原子和添加甲基的顺序是随机的，需要根据实际情况调整，这里是简版的示范❤️
    editable_mol.AddAtom(Chem.Atom(17))  # 添加一个氯原子
    editable_mol.AddAtom(Chem.Atom(6))   # 添加一个碳原子（CH3）
    
    # 得到新的分子并转换为SMILES
    optimized_mol = editable_mol.GetMol()
    optimized_smiles.append(Chem.MolToSmiles(optimized_mol))

# 选取前50个优化分子
optimized_smiles_50 = optimized_smiles[:50]

# 输出优化的SMILES字符串
for i, smiles in enumerate(optimized_smiles_50):
    print(f"Optimized molecule {i+1}: {smiles}")
# Out:
# MCS SMILES: C:C(:C)C1:N:N(C):C2:N:C:N:C(N):C:1:2
# Optimized molecule 1: C.CC(C)n1nc(-c2cccc(O)c2)c2c(N)ncnc21.Cl
# Optimized molecule 2: C.Cl.Nc1ncnc2c1c(-c1ccc(Cl)c(O)c1)nn2C1CCCC1
# Optimized molecule 3: C.Cl.Nc1ncnc2c1c(-c1ccc3[nH]ccc3c1)nn2C1CCCC1
# Optimized molecule 4: C.CC(C)n1nc(-c2ccc3cc(O)ccc3c2)c2c(N)ncnc21.Cl
# Optimized molecule 5: C.Cc1ccc(-c2nn(C(C)C)c3ncnc(N)c23)cc1O.Cl
# Optimized molecule 6: C.CC(C)n1nc(-c2cnc3[nH]ccc3c2)c2c(N)ncnc21.Cl
# Optimized molecule 7: C.CC(C)n1nc(-c2ccc(Cl)c(O)c2)c2c(N)ncnc21.Cl
# Optimized molecule 8: C.Cl.Nc1ncnc2c1c(-c1ccc(Br)c(O)c1)nn2C1CCC1
# Optimized molecule 9: C.CCC(C)n1nc(-c2ccc(C)c(O)c2)c2c(N)ncnc21.Cl
# Optimized molecule 10: C.CC(C)n1nc(-c2cc(O)cc(Br)c2)c2c(N)ncnc21.Cl
# Optimized molecule 11: C.Cl.Nc1ncnc2c1c(-c1cc(O)cc(F)c1)nn2C1CCCC1
# Optimized molecule 12: C.COc1ccc(-c2nn(C3CCC(C)C3)c3ncnc(N)c23)cc1O.Cl
# Optimized molecule 13: C.Cl.Nc1ncnc2c1c(-c1ccc(Br)c(O)c1)nn2C1CCCC1
# Optimized molecule 14: C.CC(C)n1nc(-c2ccc(Br)c(O)c2)c2c(N)ncnc21.Cl
# Optimized molecule 15: C.Cl.Nc1ncnc2c1c(-c1ccc(Cl)c(O)c1)nn2C1CCC1
# Optimized molecule 16: C.Cl.Nc1ncnc2c1c(-c1ccc(Cl)c(O)c1)nn2[C@H]1CCOC1
# Optimized molecule 17: C.CC(C)n1nc(-c2ccc(F)c(O)c2)c2c(N)ncnc21.Cl
# Optimized molecule 18: C.CC(C)n1nc(-c2ccc3[nH]ccc3c2)c2c(N)ncnc21.Cl
# Optimized molecule 19: C.CC1CCC(n2nc(-c3ccc(F)c(O)c3)c3c(N)ncnc32)C1.Cl
# Optimized molecule 20: C.CC(C)n1nc(-c2cc(O)cc(F)c2)c2c(N)ncnc21.Cl
# Optimized molecule 21: C.Cl.Nc1ncnc2c1c(-c1ccc(Cl)c(O)c1)nn2[C@@H]1CCOC1
# Optimized molecule 22: C.Cl.Nc1ncnc2c1c(-c1ccc(F)c(O)c1)nn2C1CCCC1
# Optimized molecule 23: C.CCOc1ccc(-c2nn(C3CCCC3)c3ncnc(N)c23)cc1O.Cl
# Optimized molecule 24: C.COc1ccc(-c2nn(C(C)C)c3ncnc(N)c23)cc1O.Cl
# Optimized molecule 25: C.Cc1ccc(-c2nn(C)c3ncnc(N)c23)cc1O.Cl
# Optimized molecule 26: C.Cl.Nc1ncnc2c1c(-c1ccc(F)c(O)c1)nn2C1CCCCCC1
# Optimized molecule 27: C.COc1cc(-c2nn(C(C)C)c3ncnc(N)c23)ccc1NC(C)CO.Cl
# Optimized molecule 28: C.Cc1cc(O)ccc1-c1nn(C(C)C)c2ncnc(N)c12.Cl
# Optimized molecule 29: C.COc1ccc(-c2nn(C3CCCC3)c3ncnc(N)c23)cc1O.Cl
# Optimized molecule 30: C.CCn1nc(-c2ccc(OC)c(O)c2)c2c(N)ncnc21.Cl
# Optimized molecule 31: C.CC(C)n1nc(-c2ccc3[nH]ncc3c2)c2c(N)ncnc21.Cl
# Optimized molecule 32: C.CC(C)n1nc(-c2ccc3ncccc3c2)c2c(N)ncnc21.Cl
# Optimized molecule 33: C.Cl.Nc1ncnc2c1c(-c1ccc3cn[nH]c3c1)nn2C1CCCC1
# Optimized molecule 34: C.Cl.Nc1ncnc2c1c(-c1ccc(F)c(O)c1)nn2[C@H]1CCNC1
# Optimized molecule 35: C.Cl.Nc1ncnc2c1c(-c1ccc(F)c(O)c1)nn2[C@H]1CCOC1
# Optimized molecule 36: C.Cl.Nc1ncnc2c1c(-c1ccc3[nH]ncc3c1)nn2C1CCCC1
# Optimized molecule 37: C.CC(C)n1nc(-c2ccc3cn[nH]c3c2)c2c(N)ncnc21.Cl
# Optimized molecule 38: C.CC(C)n1nc(-c2ccc3cc[nH]c3c2)c2c(N)ncnc21.Cl
# Optimized molecule 39: C.Cl.Nc1ncnc2c1c(-c1ccc(F)c(O)c1)nn2C1CCC1
# Optimized molecule 40: C.CCOc1ccc2cc(-c3nn(C)c4ncnc(N)c34)ccc2c1.Cl
# Optimized molecule 41: C.C[C@H](CN)n1nc(-c2ccc(Cl)c(O)c2)c2c(N)ncnc21.Cl
# Optimized molecule 42: C.Cl.Nc1ncnc2c1c(-c1ccc(F)c(O)c1)nn2[C@@H]1CCOC1
# Optimized molecule 43: C.CC(C)n1nc(-c2ccc3c(ccn3C)c2)c2c(N)ncnc21.Cl
# Optimized molecule 44: C.Cl.Nc1ncnc2c1c(-c1cccc(O)c1F)nn2C1CCCC1
# Optimized molecule 45: C.COc1cc(Br)cc(-c2nn(C(C)C)c3ncnc(N)c23)c1.Cl
# Optimized molecule 46: C.Cl.Cn1nc(-c2ccc3ccccc3c2)c2c(N)ncnc21
# Optimized molecule 47: C.Cc1ccc2cc(-c3nn(C(C)C)c4ncnc(N)c34)ccc2n1.Cl
# Optimized molecule 48: C.C[C@@H](CN)n1nc(-c2ccc(Cl)c(O)c2)c2c(N)ncnc21.Cl
# Optimized molecule 49: C.Cl.Nc1ncnc2c1c(-c1ccc(F)c(O)c1)nn2C1CNC1
# Optimized molecule 50: C.COc1ccc(-c2nn(C3CNC3)c3ncnc(N)c23)cc1O.Cl

# %% [markdown]
# # 注意：前面这个版本是非常简单的示例版本，下面我们才是进入正真的化合物设计环节。

# %% [markdown]
# # 2. 设计化合物

# %%
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors, QED
import pandas as pd

# 加载SDF文件
sdf_file = str(HERE / "../05_Compound_clustering/data/molecule_set_largest_cluster.sdf")
supplier = Chem.SDMolSupplier(sdf_file)

# 过滤有效的分子
molecules = [mol for mol in supplier if mol is not None]

# 计算最大公共子结构（MCS）
mcs_result = rdFMCS.FindMCS(molecules)
mcs_smarts = mcs_result.smartsString
mcs_mol = Chem.MolFromSmarts(mcs_smarts)

# 将MCS转换为SMILES格式以供参考
mcs_smiles = Chem.MolToSmiles(mcs_mol)
print("MCS SMILES:", mcs_smiles)

# 评估分子是否符合Lipinski's Rule of Five
def lipinski_rule_of_five(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)
    
    # Lipinski's Rule of Five
    return mol_weight <= 500 and logp <= 5 and hbd <= 5 and hba <= 10

# 评估分子是否符合CNS药物设计规则
def cns_drug_likeness(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    tpsa = Descriptors.TPSA(mol)
    
    # CNS药物规则：分子量小于400，logP在2到3之间，TPSA小于90
    return mol_weight <= 400 and 2 <= logp <= 3 and tpsa <= 90

# 初始化结果列表
results = []

# 对每个分子进行优化并计算属性
for i, mol in enumerate(molecules):
    # 创建可编辑的分子副本以进行修改
    mol_copy = Chem.Mol(mol)
    editable_mol = Chem.EditableMol(mol_copy)
    
    # 添加一个氯原子（Cl）和一个甲基（CH3）作为优化示例
    chlorine_atom = Chem.Atom(17)  # 氯原子
    carbon_atom = Chem.Atom(6)     # 碳原子（用于甲基）

    editable_mol.AddAtom(chlorine_atom)
    editable_mol.AddAtom(carbon_atom)
    
    # 获取优化后的分子并进行氢原子的补充计算
    optimized_mol = editable_mol.GetMol()
    AllChem.Compute2DCoords(optimized_mol)  # 重新计算坐标
    AllChem.AddHs(optimized_mol)  # 添加隐式氢原子

    # 计算QED分数
    qed_score = QED.qed(optimized_mol)
    
    # 检查是否符合Lipinski's Rule of Five和CNS药物设计规则
    lipinski_pass = lipinski_rule_of_five(optimized_mol)
    cns_pass = cns_drug_likeness(optimized_mol)
    
    # 将结果保存到列表中
    results.append({
        'id': i,
        'smiles': Chem.MolToSmiles(optimized_mol),
        'QED': qed_score,
        'Lipinski': lipinski_pass,
        'CNS': cns_pass
    })

# 将结果保存为CSV文件
df = pd.DataFrame(results)
output_file = DATA / "filtered_drug_like_molecules.csv"
df.to_csv(output_file, index=False)

print(f"已将筛选后的分子保存为CSV文件: {output_file}")
# Out:
# MCS SMILES: C:C(:C)C1:N:N(C):C2:N:C:N:C(N):C:1:2
# 已将筛选后的分子保存为CSV文件: /Users/wangyang/Desktop/AIDD/07_Compound_design_based_on_molecule_set_largest_cluster/data/filtered_drug_like_molecules.csv

# %% [markdown]
# ## 3. 第二版优化

# %%
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors, QED
import pandas as pd

# 加载SDF文件
sdf_file = str(HERE / "../05_Compound_clustering/data/molecule_set_largest_cluster.sdf")
supplier = Chem.SDMolSupplier(sdf_file)

# 过滤有效的分子
molecules = [mol for mol in supplier if mol is not None]

# 计算最大公共子结构（MCS）
mcs_result = rdFMCS.FindMCS(molecules)
mcs_smarts = mcs_result.smartsString
mcs_mol = Chem.MolFromSmarts(mcs_smarts)

# 将MCS转换为SMILES格式以供参考
mcs_smiles = Chem.MolToSmiles(mcs_mol)
print("MCS SMILES:", mcs_smiles)

# 评估分子是否符合Lipinski's Rule of Five
def lipinski_rule_of_five(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)
    
    # Lipinski's Rule of Five
    return mol_weight <= 500 and logp <= 5 and hbd <= 5 and hba <= 10

# 评估分子是否符合CNS药物设计规则
def cns_drug_likeness(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    tpsa = Descriptors.TPSA(mol)
    
    # CNS药物规则：分子量小于400，logP在2到3之间，TPSA小于90
    return mol_weight <= 400 and 2 <= logp <= 3 and tpsa <= 90

# 计算分子的额外属性
def calculate_additional_properties(mol):
    # 脂水分布系数
    logp = Descriptors.MolLogP(mol)

    # 氢键供体和受体
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)

    # 芳香环和非芳香环数目
    num_aromatic_rings = Chem.rdMolDescriptors.CalcNumAromaticRings(mol)
    num_aliphatic_rings = Chem.rdMolDescriptors.CalcNumAliphaticRings(mol)

    # 计算非碳原子数占非氢原子数的比率
    num_atoms = mol.GetNumAtoms()
    num_non_h_atoms = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() > 1)  # 非氢原子
    num_non_c_atoms = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() != 6)  # 非碳原子
    non_c_ratio = num_non_c_atoms / num_non_h_atoms if num_non_h_atoms > 0 else 0

    return logp, hbd, hba, num_aromatic_rings, num_aliphatic_rings, non_c_ratio

# 初始化结果列表
results = []

# 对每个分子进行优化并计算属性
for i, mol in enumerate(molecules):
    # 创建可编辑的分子副本以进行修改
    mol_copy = Chem.Mol(mol)
    editable_mol = Chem.EditableMol(mol_copy)
    
    # 添加一个氯原子（Cl）和一个甲基（CH3）作为优化示例
    chlorine_atom = Chem.Atom(17)  # 氯原子
    carbon_atom = Chem.Atom(6)     # 碳原子（用于甲基）

    editable_mol.AddAtom(chlorine_atom)
    editable_mol.AddAtom(carbon_atom)
    
    # 获取优化后的分子并进行氢原子的补充计算
    optimized_mol = editable_mol.GetMol()
    AllChem.Compute2DCoords(optimized_mol)  # 重新计算坐标
    AllChem.AddHs(optimized_mol)  # 添加隐式氢原子

    # 计算QED分数
    qed_score = QED.qed(optimized_mol)
    
    # 检查是否符合Lipinski's Rule of Five和CNS药物设计规则
    lipinski_pass = lipinski_rule_of_five(optimized_mol)
    cns_pass = cns_drug_likeness(optimized_mol)

    # 计算额外的分子属性
    logp, hbd, hba, num_aromatic_rings, num_aliphatic_rings, non_c_ratio = calculate_additional_properties(optimized_mol)
    
    # 将结果保存到列表中
    results.append({
        'id': i,
        'smiles': Chem.MolToSmiles(optimized_mol),
        'QED': qed_score,
        'Lipinski': lipinski_pass,
        'CNS': cns_pass,
        'LogP': logp,
        'HBD': hbd,
        'HBA': hba,
        'Aromatic Rings': num_aromatic_rings,
        'Aliphatic Rings': num_aliphatic_rings,
        'Non-C Ratio': non_c_ratio
    })

# 将结果保存为CSV文件
df = pd.DataFrame(results)
output_file = DATA / "filtered_drug_like_molecules_with_properties.csv"
df.to_csv(output_file, index=False)

print(f"已将筛选后的分子保存为CSV文件: {output_file}")
# Out:
# MCS SMILES: C:C(:C)C1:N:N(C):C2:N:C:N:C(N):C:1:2
# 已将筛选后的分子保存为CSV文件: /Users/wangyang/Desktop/AIDD/07_Compound_design_based_on_molecule_set_largest_cluster/data/filtered_drug_like_molecules_with_properties.csv

# %% [markdown]
# # 4. 第三版优化

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors, QED
import torch
import torch.nn as nn
from torch_geometric.data import Data
from sklearn.model_selection import train_test_split

# 读取EGFR compounds数据
egfr_csv_file = str(HERE / "../03_Molecular_filtration_of_unwanted_substructures/data/data_clean_PAINS.csv")
egfr_df = pd.read_csv(egfr_csv_file)

# 根据pIC50值划分数据集（假设pIC50列名为"pIC50"）
high_activity_df = egfr_df[egfr_df["pIC50"] >= 8]  # 活性较好的数据（pIC50 >= 8）
low_activity_df = egfr_df[egfr_df["pIC50"] < 8]    # 活性较低的数据

# 加载SDF文件
sdf_file = str(HERE / "../05_Compound_clustering/data/molecule_set_largest_cluster.sdf")
supplier = Chem.SDMolSupplier(sdf_file)

# 过滤有效分子
molecules = [mol for mol in supplier if mol is not None]

# 构建GCN模型
class GCN(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GCN, self).__init__()
        self.conv1 = nn.Linear(input_dim, hidden_dim)
        self.conv2 = nn.Linear(hidden_dim, output_dim)
        self.fc = nn.Linear(output_dim, 1)

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = torch.relu(self.conv2(x))
        x = torch.mean(x, dim=0)
        return self.fc(x)

# 将SMILES转换为分子图
def smiles_to_graph(smiles):
    mol = Chem.MolFromSmiles(smiles)
    atoms = [atom.GetAtomicNum() for atom in mol.GetAtoms()]
    bonds = []
    for bond in mol.GetBonds():
        bonds.append((bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()))
    data = Data(x=torch.tensor(atoms, dtype=torch.float).view(-1, 1),
                edge_index=torch.tensor(bonds, dtype=torch.long).t().contiguous())
    return data

# 将数据集转换为图表示
high_activity_smiles = high_activity_df["smiles"].values
high_activity_data_list = [smiles_to_graph(smiles) for smiles in high_activity_smiles]

# 训练集和测试集划分
train_data, test_data = train_test_split(high_activity_data_list, test_size=0.2, random_state=2)

# 使用GCN模型预测并优化分子
def optimize_molecule(mol, model):
    mol_data = smiles_to_graph(Chem.MolToSmiles(mol))
    return model(mol_data.x)

# 创建GCN模型实例
input_dim = 1
hidden_dim = 32
output_dim = 16
model = GCN(input_dim, hidden_dim, output_dim)

# 训练模型
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
loss_fn = nn.MSELoss()

for epoch in range(100):
    model.train()
    total_loss = 0
    for data in train_data:
        optimizer.zero_grad()
        output = model(data.x)
        # 这里的目标值可以根据EGFR活性数据进行修改
        target = torch.tensor([1.0], dtype=torch.float)  # 示例目标
        loss = loss_fn(output, target)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f'Epoch {epoch}, Loss: {total_loss}')

# 评估分子是否符合Lipinski's Rule of Five
def lipinski_rule_of_five(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)
    
    # Lipinski's Rule of Five
    return mol_weight <= 500 and logp <= 5 and hbd <= 5 and hba <= 10

# 评估分子是否符合CNS药物设计规则
def cns_drug_likeness(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    tpsa = Descriptors.TPSA(mol)
    
    # CNS药物规则：分子量小于400，logP在2到3之间，TPSA小于90
    return mol_weight <= 400 and 2 <= logp <= 3 and tpsa <= 90

# 计算分子的额外属性
def calculate_additional_properties(mol):
    logp = Descriptors.MolLogP(mol)
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)
    num_aromatic_rings = Chem.rdMolDescriptors.CalcNumAromaticRings(mol)
    num_aliphatic_rings = Chem.rdMolDescriptors.CalcNumAliphaticRings(mol)
    num_non_h_atoms = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() > 1)
    num_non_c_atoms = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() != 6)
    non_c_ratio = num_non_c_atoms / num_non_h_atoms if num_non_h_atoms > 0 else 0
    return logp, hbd, hba, num_aromatic_rings, num_aliphatic_rings, non_c_ratio

# 优化并生成新分子
optimized_results = []
for mol in molecules:
    optimized_score = optimize_molecule(mol, model)
    smiles = Chem.MolToSmiles(mol)
    qed_score = QED.qed(mol)
    
    # 评估分子是否符合药物设计规则
    lipinski_pass = lipinski_rule_of_five(mol)
    cns_pass = cns_drug_likeness(mol)
    logp, hbd, hba, num_aromatic_rings, num_aliphatic_rings, non_c_ratio = calculate_additional_properties(mol)

    # 只保留符合所有规则且QED大于0.7的分子
    if qed_score > 0.7 and lipinski_pass and cns_pass:
        optimized_results.append({
            "smiles": smiles,
            "optimized_score": optimized_score.item(),
            "QED": qed_score,
            "Lipinski": lipinski_pass,
            "CNS": cns_pass,
            "LogP": logp,
            "HBD": hbd,
            "HBA": hba,
            "Aromatic Rings": num_aromatic_rings,
            "Aliphatic Rings": num_aliphatic_rings,
            "Non-C Ratio": non_c_ratio
        })

# 保存优化后的分子为CSV文件
df = pd.DataFrame(optimized_results)
output_file = DATA / "optimized_drug_like_molecules_with_properties.csv"
df.to_csv(output_file, index=False)

print(f"Optimized molecules saved to: {output_file}")
# Out:
# Epoch 0, Loss: 9.611027431787093
# Epoch 1, Loss: 0.9213227759447307
# Epoch 2, Loss: 0.3889081697072676
# Epoch 3, Loss: 0.1589148537424343
# Epoch 4, Loss: 0.005177952429495036
# Epoch 5, Loss: 0.00012733732922498575
# Epoch 6, Loss: 7.911567916352169e-06
# Epoch 7, Loss: 1.442878791024782e-05
# Epoch 8, Loss: 1.6120945289799238e-05
# Epoch 9, Loss: 0.00021395458589879013
# Epoch 10, Loss: 0.043886429220794554
# Epoch 11, Loss: 0.014295512936616461
# Epoch 12, Loss: 0.08614812327619603
# Epoch 13, Loss: 0.004251621019609075
# Epoch 14, Loss: 0.003809922293481094
# Epoch 15, Loss: 0.09549353515788894
# Epoch 16, Loss: 0.012750155173755218
# Epoch 17, Loss: 0.0070961742023385455
# Epoch 18, Loss: 0.003297374927701213
# Epoch 19, Loss: 0.005353061383225111
# Epoch 20, Loss: 0.003140471505172826
# Epoch 21, Loss: 0.003103601943646339
# Epoch 22, Loss: 0.00747722761012426
# Epoch 23, Loss: 0.006025301755375523
# Epoch 24, Loss: 0.0034294636748875007
# Epoch 25, Loss: 0.007731810719004528
# Epoch 26, Loss: 0.0007832477753098033
# Epoch 27, Loss: 0.00637390817989214
# Epoch 28, Loss: 0.00020716353378347208
# Epoch 29, Loss: 0.005708170490173359
# Epoch 30, Loss: 0.001553818264763862
# Epoch 31, Loss: 0.006377285180697356
# Epoch 32, Loss: 1.0748592750076114e-05
# Epoch 33, Loss: 0.0016430690694804184
# Epoch 34, Loss: 0.0031755641073338836
# Epoch 35, Loss: 0.0004275766258992064
# Epoch 36, Loss: 0.002647191766769197
# Epoch 37, Loss: 0.0004890396649095408
# Epoch 38, Loss: 0.00316126889541124
# Epoch 39, Loss: 0.000283062331302375
# Epoch 40, Loss: 0.007497159045559698
# Epoch 41, Loss: 0.0010619527026918263
# Epoch 42, Loss: 3.735613066169208e-05
# Epoch 43, Loss: 2.9707971549441936e-07
# Epoch 44, Loss: 0.00012129917795533629
# Epoch 45, Loss: 0.0009583237281169943
# Epoch 46, Loss: 4.683146040562747e-05
# Epoch 47, Loss: 0.0002327581091527975
# Epoch 48, Loss: 0.0006545795324051085
# Epoch 49, Loss: 0.00012588453627770946
# Epoch 50, Loss: 0.0009248241542891833
# Epoch 51, Loss: 4.1538830210186006e-05
# Epoch 52, Loss: 1.1872266423296196e-05
# Epoch 53, Loss: 0.0004315082564403383
# Epoch 54, Loss: 3.856615649056039e-08
# Epoch 55, Loss: 0.00030837889918444716
# Epoch 56, Loss: 8.1453766966888e-06
# Epoch 57, Loss: 8.544311924651993e-10
# Epoch 58, Loss: 0.0001359710898753974
# Epoch 59, Loss: 4.902957703833977e-05
# Epoch 60, Loss: 3.88928729009308e-05
# Epoch 61, Loss: 5.6468836653778e-05
# Epoch 62, Loss: 5.957342739648652e-05
# Epoch 63, Loss: 3.371254772233101e-05
# Epoch 64, Loss: 5.456044953078276e-05
# Epoch 65, Loss: 2.45759074530838e-05
# Epoch 66, Loss: 3.5276393319350063e-05
# Epoch 67, Loss: 3.805601677342452e-05
# Epoch 68, Loss: 3.9076306091345714e-05
# Epoch 69, Loss: 3.549939431479743e-05
# Epoch 70, Loss: 4.515905738955439e-05
# Epoch 71, Loss: 3.0920765166086994e-05
# Epoch 72, Loss: 9.213153123610596e-05
# Epoch 73, Loss: 6.754411337794863e-06
# Epoch 74, Loss: 3.775160605101746e-05
# Epoch 75, Loss: 7.332801033044234e-12
# Epoch 76, Loss: 0.0
# Epoch 77, Loss: 0.0
# Epoch 78, Loss: 0.0
# Epoch 79, Loss: 0.0
# Epoch 80, Loss: 0.0
# Epoch 81, Loss: 0.0
# Epoch 82, Loss: 0.0
# Epoch 83, Loss: 0.0
# Epoch 84, Loss: 0.0
# Epoch 85, Loss: 0.0
# Epoch 86, Loss: 0.0
# Epoch 87, Loss: 0.0
# Epoch 88, Loss: 0.0
# Epoch 89, Loss: 0.0
# Epoch 90, Loss: 0.0
# Epoch 91, Loss: 0.0
# Epoch 92, Loss: 0.0
# Epoch 93, Loss: 0.0
# Epoch 94, Loss: 0.0
# Epoch 95, Loss: 0.0
# Epoch 96, Loss: 0.0
# Epoch 97, Loss: 0.0
# Epoch 98, Loss: 0.0
# Epoch 99, Loss: 0.0
# Optimized molecules saved to: /Users/wangyang/Desktop/AIDD/07_Compound_design_based_on_molecule_set_largest_cluster/data/optimized_drug_like_molecules_with_properties.csv

# %% [markdown]
# ## 5.第四版优化
# - 需要增加clintox来预测毒性
# - 增加了一些属性，如logp、hbd、hba、aromatic ring、aliphatic ring、non-c ratio
# - 增加了clintox预测
# - 增加了一些筛选条件，如分子量、logp、tpsa、hba、hbd、aromatic ring、aliphatic ring、non-c ratio
