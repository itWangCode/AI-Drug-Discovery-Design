# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import rdFMCS

# Load the SDF file
sdf_file = "molecule_set_largest_cluster.sdf"
supplier = Chem.SDMolSupplier(sdf_file)

# Filter valid molecules
molecules = [mol for mol in supplier if mol is not None]

# Compute the Maximum Common Substructure (MCS)
mcs_result = rdFMCS.FindMCS(molecules)
mcs_smarts = mcs_result.smartsString
mcs_mol = Chem.MolFromSmarts(mcs_smarts)

# Convert MCS to SMILES for reference
mcs_smiles = Chem.MolToSmiles(mcs_mol)
print("MCS SMILES:", mcs_smiles)

# Perform optimizations on each molecule by adding fragments (e.g., halogens, methyl groups)
optimized_smiles = []
for mol in molecules:
    # Create editable molecule
    editable_mol = Chem.EditableMol(mol)
    
    # Add an example optimization, such as adding a chlorine atom (Cl) and a methyl group (-CH3)
    editable_mol.AddAtom(Chem.Atom(17))  # Add a chlorine atom
    editable_mol.AddAtom(Chem.Atom(6))   # Add a carbon atom (CH3)
    
    # Get the new molecule and convert to SMILES
    optimized_mol = editable_mol.GetMol()
    optimized_smiles.append(Chem.MolToSmiles(optimized_mol))

# Select the first 50 optimized molecules
optimized_smiles_50 = optimized_smiles[:50]

# Output optimized SMILES strings
for i, smiles in enumerate(optimized_smiles_50):
    print(f"Optimized molecule {i+1}: {smiles}")
# Out:
# MCS SMILES: CCOC1:C:C2:N:C:N:C(NC3:C:C:C:C:C:3):C:2:C:C:1NC(C)=O
# Optimized molecule 1: C.C=CC(=O)NCCOc1cc2ncnc(Nc3ccc(Br)cc3F)c2cc1NC(=O)C=C.Cl
# Optimized molecule 2: C.C=CC(=O)Nc1cc2c(Nc3ccc(F)c(Br)c3)ncnc2cc1OCCCN1CCOCC1.Cl
# Optimized molecule 3: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCCNC(=O)CN(C)C.Cl
# Optimized molecule 4: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)NCC.Cl
# Optimized molecule 5: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)CN(C)C.Cl
# Optimized molecule 6: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(C)=O.Cl
# Optimized molecule 7: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCCNC.Cl
# Optimized molecule 8: C.COCCOc1cc2ncnc(Nc3ccc(Br)cc3F)c2cc1NC(=O)/C=C/CN(C)C.Cl
# Optimized molecule 9: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNCC(C)=O.Cl
# Optimized molecule 10: C.C=CC(=O)Nc1cc2c(Nc3cccc(Br)c3)ncnc2cc1OCCCN1CCOCC1.Cl
# Optimized molecule 11: C.C=CC(=O)Nc1cc2c(Nc3cc(Cl)c(Cl)cc3F)ncnc2cc1OCCNCC(C)=O.Cl
# Optimized molecule 12: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCCNC(C)=O.Cl
# Optimized molecule 13: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCN.Cl
# Optimized molecule 14: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(N)=O.Cl
# Optimized molecule 15: C.C=CC(=O)Nc1cc2c(Nc3cc(Cl)c(Cl)cc3F)ncnc2cc1OCCNC(C)=O.Cl
# Optimized molecule 16: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)C(F)F.Cl
# Optimized molecule 17: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C(=O)CN(C)C)CC1.Cl
# Optimized molecule 18: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)CN1CCCCC1.Cl
# Optimized molecule 19: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)C1CC1.Cl
# Optimized molecule 20: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)c(Cl)c3F)ncnc2cc1OCCNC(=O)NCC.Cl
# Optimized molecule 21: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)CCN(C)C.Cl
# Optimized molecule 22: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCN(C)C.Cl
# Optimized molecule 23: C.C=CC(=O)Nc1cc2c(Nc3cc(Cl)c(Br)cc3F)ncnc2cc1OCCNC(=O)CN(C)C.Cl
# Optimized molecule 24: C.C=CC(=O)Nc1cc2c(Nc3cc(Cl)c(Cl)cc3F)ncnc2cc1OCCNC(=O)CN(C)C.Cl
# Optimized molecule 25: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCCCNC(C)=O.Cl
# Optimized molecule 26: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCCNC(=O)NCC.Cl
# Optimized molecule 27: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)CN1CCN(C)CC1.Cl
# Optimized molecule 28: C.C=CC(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2cc1OCCNC(C)=O.Cl
# Optimized molecule 29: C.C=CC(=O)Nc1cc2c(Nc3cc(F)c(Br)cc3F)ncnc2cc1OCCNC(C)=O.Cl
# Optimized molecule 30: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)c(Cl)c3F)ncnc2cc1OCCNC(C)=O.Cl
# Optimized molecule 31: C.C=CC(=O)Nc1cc2c(Nc3cc(Cl)c(Br)cc3F)ncnc2cc1OCCNCC(C)=O.Cl
# Optimized molecule 32: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)N1CCN(C)CC1.Cl
# Optimized molecule 33: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)COC.Cl
# Optimized molecule 34: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)CCN1CCCCC1.Cl
# Optimized molecule 35: C.C=CC(=O)Nc1cc2c(Nc3ccc(F)c(F)c3F)ncnc2cc1OCCNC(C)=O.Cl
# Optimized molecule 36: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)c(Cl)c3F)ncnc2cc1OCCNCC(C)=O.Cl
# Optimized molecule 37: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C(N)=O)CC1.Cl
# Optimized molecule 38: C.C=CC(=O)Nc1cc2c(Nc3cc(Cl)c(Br)cc3F)ncnc2cc1OCCNC(C)=O.Cl
# Optimized molecule 39: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)/C=C/CN(C)C.Cl
# Optimized molecule 40: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)c(Cl)c3F)ncnc2cc1OCCNC(=O)CO.Cl
# Optimized molecule 41: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)c(F)c3F)ncnc2cc1OCCNC(=O)CN(C)C.Cl
# Optimized molecule 42: C.C=CC(=O)Nc1cc2c(Nc3ccc(Cl)cc3F)ncnc2cc1OCCNC(C)=O.Cl
# Optimized molecule 43: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)C(C)N.Cl
# Optimized molecule 44: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)c(F)c3F)ncnc2cc1OCCNC(=O)CCN(CC)CC.Cl
# Optimized molecule 45: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)/C=C/C.Cl
# Optimized molecule 46: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)c(Cl)c3F)ncnc2cc1OCCNC(=O)CN(C)C.Cl
# Optimized molecule 47: C.C=CCNC(=O)NCCOc1cc2ncnc(Nc3ccc(Br)cc3F)c2cc1NC(=O)C=C.Cl
# Optimized molecule 48: C.C=CC(=O)Nc1cc2c(Nc3cc(Cl)c(Cl)cc3F)ncnc2cc1OCCNC(=O)COC.Cl
# Optimized molecule 49: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCCNC(=O)NC(C)CC.Cl
# Optimized molecule 50: C.C=CC(=O)Nc1cc2c(Nc3ccc(Br)c(Cl)c3F)ncnc2cc1OCCNC(=O)CCOC.Cl

# %%
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors, QED
import pandas as pd

# 加载SDF文件
sdf_file = "molecule_set_largest_cluster.sdf"
supplier = Chem.SDMolSupplier(sdf_file)

# 过滤有效的分子
molecules = [mol for mol in supplier if mol is not None]

# 计算最大公共子结构（MCS）
mcs_result = rdFMCS.FindMCS(molecules)
mcs_smarts = mcs_result.smartsString
mcs_mol = Chem.MolFromSmarts(mcs_smarts)

# 将MCS转换为SMILES格式以供参考
mcs_smiles = Chem.MolToSmiles(mcs_mol)
print("MCS SMILES:", mcs_smiles)

# 评估分子是否符合Lipinski's Rule of Five
def lipinski_rule_of_five(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)
    
    # Lipinski's Rule of Five
    return mol_weight <= 500 and logp <= 5 and hbd <= 5 and hba <= 10

# 评估分子是否符合CNS药物设计规则
def cns_drug_likeness(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    tpsa = Descriptors.TPSA(mol)
    
    # CNS药物规则：分子量小于400，logP在2到3之间，TPSA小于90
    return mol_weight <= 400 and 2 <= logp <= 3 and tpsa <= 90

# 初始化结果列表
results = []

# 对每个分子进行优化并计算属性
for i, mol in enumerate(molecules):
    # 创建可编辑的分子副本以进行修改
    mol_copy = Chem.Mol(mol)
    editable_mol = Chem.EditableMol(mol_copy)
    
    # 添加一个氯原子（Cl）和一个甲基（CH3）作为优化示例
    chlorine_atom = Chem.Atom(17)  # 氯原子
    carbon_atom = Chem.Atom(6)     # 碳原子（用于甲基）

    editable_mol.AddAtom(chlorine_atom)
    editable_mol.AddAtom(carbon_atom)
    
    # 获取优化后的分子并进行氢原子的补充计算
    optimized_mol = editable_mol.GetMol()
    AllChem.Compute2DCoords(optimized_mol)  # 重新计算坐标
    AllChem.AddHs(optimized_mol)  # 添加隐式氢原子

    # 计算QED分数
    qed_score = QED.qed(optimized_mol)
    
    # 检查是否符合Lipinski's Rule of Five和CNS药物设计规则
    lipinski_pass = lipinski_rule_of_five(optimized_mol)
    cns_pass = cns_drug_likeness(optimized_mol)
    
    # 将结果保存到列表中
    results.append({
        'id': i,
        'smiles': Chem.MolToSmiles(optimized_mol),
        'QED': qed_score,
        'Lipinski': lipinski_pass,
        'CNS': cns_pass
    })

# 将结果保存为CSV文件
df = pd.DataFrame(results)
output_file = "filtered_drug_like_molecules.csv"
df.to_csv(output_file, index=False)

print(f"已将筛选后的分子保存为CSV文件: {output_file}")
# Out:
# MCS SMILES: CCOC1:C:C2:N:C:N:C(NC3:C:C:C:C:C:3):C:2:C:C:1NC(C)=O
# 已将筛选后的分子保存为CSV文件: filtered_drug_like_molecules.csv

# %%
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors, QED
import pandas as pd

# 加载SDF文件
sdf_file = "molecule_set_largest_cluster.sdf"
supplier = Chem.SDMolSupplier(sdf_file)

# 过滤有效的分子
molecules = [mol for mol in supplier if mol is not None]

# 计算最大公共子结构（MCS）
mcs_result = rdFMCS.FindMCS(molecules)
mcs_smarts = mcs_result.smartsString
mcs_mol = Chem.MolFromSmarts(mcs_smarts)

# 将MCS转换为SMILES格式以供参考
mcs_smiles = Chem.MolToSmiles(mcs_mol)
print("MCS SMILES:", mcs_smiles)

# 评估分子是否符合Lipinski's Rule of Five
def lipinski_rule_of_five(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)
    
    # Lipinski's Rule of Five
    return mol_weight <= 500 and logp <= 5 and hbd <= 5 and hba <= 10

# 评估分子是否符合CNS药物设计规则
def cns_drug_likeness(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    tpsa = Descriptors.TPSA(mol)
    
    # CNS药物规则：分子量小于400，logP在2到3之间，TPSA小于90
    return mol_weight <= 400 and 2 <= logp <= 3 and tpsa <= 90

# 计算分子的额外属性
def calculate_additional_properties(mol):
    # 脂水分布系数
    logp = Descriptors.MolLogP(mol)

    # 氢键供体和受体
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)

    # 芳香环和非芳香环数目
    num_aromatic_rings = Chem.rdMolDescriptors.CalcNumAromaticRings(mol)
    num_aliphatic_rings = Chem.rdMolDescriptors.CalcNumAliphaticRings(mol)

    # 计算非碳原子数占非氢原子数的比率
    num_atoms = mol.GetNumAtoms()
    num_non_h_atoms = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() > 1)  # 非氢原子
    num_non_c_atoms = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() != 6)  # 非碳原子
    non_c_ratio = num_non_c_atoms / num_non_h_atoms if num_non_h_atoms > 0 else 0

    return logp, hbd, hba, num_aromatic_rings, num_aliphatic_rings, non_c_ratio

# 初始化结果列表
results = []

# 对每个分子进行优化并计算属性
for i, mol in enumerate(molecules):
    # 创建可编辑的分子副本以进行修改
    mol_copy = Chem.Mol(mol)
    editable_mol = Chem.EditableMol(mol_copy)
    
    # 添加一个氯原子（Cl）和一个甲基（CH3）作为优化示例
    chlorine_atom = Chem.Atom(17)  # 氯原子
    carbon_atom = Chem.Atom(6)     # 碳原子（用于甲基）

    editable_mol.AddAtom(chlorine_atom)
    editable_mol.AddAtom(carbon_atom)
    
    # 获取优化后的分子并进行氢原子的补充计算
    optimized_mol = editable_mol.GetMol()
    AllChem.Compute2DCoords(optimized_mol)  # 重新计算坐标
    AllChem.AddHs(optimized_mol)  # 添加隐式氢原子

    # 计算QED分数
    qed_score = QED.qed(optimized_mol)
    
    # 检查是否符合Lipinski's Rule of Five和CNS药物设计规则
    lipinski_pass = lipinski_rule_of_five(optimized_mol)
    cns_pass = cns_drug_likeness(optimized_mol)

    # 计算额外的分子属性
    logp, hbd, hba, num_aromatic_rings, num_aliphatic_rings, non_c_ratio = calculate_additional_properties(optimized_mol)
    
    # 将结果保存到列表中
    results.append({
        'id': i,
        'smiles': Chem.MolToSmiles(optimized_mol),
        'QED': qed_score,
        'Lipinski': lipinski_pass,
        'CNS': cns_pass,
        'LogP': logp,
        'HBD': hbd,
        'HBA': hba,
        'Aromatic Rings': num_aromatic_rings,
        'Aliphatic Rings': num_aliphatic_rings,
        'Non-C Ratio': non_c_ratio
    })

# 将结果保存为CSV文件
df = pd.DataFrame(results)
output_file = "filtered_drug_like_molecules_with_properties.csv"
df.to_csv(output_file, index=False)

print(f"已将筛选后的分子保存为CSV文件: {output_file}")
# Out:
# MCS SMILES: CCOC1:C:C2:N:C:N:C(NC3:C:C:C:C:C:3):C:2:C:C:1NC(C)=O
# 已将筛选后的分子保存为CSV文件: filtered_drug_like_molecules_with_properties.csv

# %%
# Updated code with logging for debugging molecule processing

from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors, QED
import pandas as pd

# Load SDF file
sdf_file = "molecule_set_largest_cluster.sdf"
supplier = Chem.SDMolSupplier(sdf_file)

# Filter valid molecules
molecules = [mol for mol in supplier if mol is not None]

# Calculate MCS
mcs_result = rdFMCS.FindMCS(molecules)
mcs_smarts = mcs_result.smartsString
mcs_mol = Chem.MolFromSmarts(mcs_smarts)

# Logging MCS result
mcs_smiles = Chem.MolToSmiles(mcs_mol)
print(f"MCS SMILES: {mcs_smiles}")

# Function to check Lipinski's Rule of Five
def lipinski_rule_of_five(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)
    return mol_weight <= 500 and logp <= 5 and hbd <= 5 and hba <= 10

# Function to check CNS drug likeness
def cns_drug_likeness(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    tpsa = Descriptors.TPSA(mol)
    return mol_weight <= 400 and 2 <= logp <= 3 and tpsa <= 90

# Additional property calculations
def calculate_additional_properties(mol):
    logp = Descriptors.MolLogP(mol)
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)
    num_aromatic_rings = Chem.rdMolDescriptors.CalcNumAromaticRings(mol)
    num_aliphatic_rings = Chem.rdMolDescriptors.CalcNumAliphaticRings(mol)
    num_non_h_atoms = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() > 1)
    num_non_c_atoms = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() != 6)
    non_c_ratio = num_non_c_atoms / num_non_h_atoms if num_non_h_atoms > 0 else 0
    return logp, hbd, hba, num_aromatic_rings, num_aliphatic_rings, non_c_ratio

# Initialize results and counters
results = []
count = 0
max_count = 100000

# Process molecules
for mol in molecules:
    # Make molecule editable and add atoms
    mol_copy = Chem.Mol(mol)
    editable_mol = Chem.EditableMol(mol_copy)
    editable_mol.AddAtom(Chem.Atom(17))  # Chlorine
    editable_mol.AddAtom(Chem.Atom(6))   # Carbon (for CH3)

    # Finalize molecule and compute properties
    optimized_mol = editable_mol.GetMol()
    AllChem.Compute2DCoords(optimized_mol)
    AllChem.AddHs(optimized_mol)

    # Compute QED score
    qed_score = QED.qed(optimized_mol)
    
    # Check filtering conditions
    lipinski_pass = lipinski_rule_of_five(optimized_mol)
    cns_pass = cns_drug_likeness(optimized_mol)

    # Logging each step
    print(f"Molecule {count}: Lipinski {lipinski_pass}, CNS {cns_pass}, QED {qed_score}")

    # Save only molecules that pass all criteria
    if lipinski_pass and cns_pass and qed_score > 0.7:
        logp, hbd, hba, num_aromatic_rings, num_aliphatic_rings, non_c_ratio = calculate_additional_properties(optimized_mol)
        results.append({
            'id': count,
            'smiles': Chem.MolToSmiles(optimized_mol),
            'QED': qed_score,
            'Lipinski': lipinski_pass,
            'CNS': cns_pass,
            'LogP': logp,
            'HBD': hbd,
            'HBA': hba,
            'Aromatic Rings': num_aromatic_rings,
            'Aliphatic Rings': num_aliphatic_rings,
            'Non-C Ratio': non_c_ratio
        })
        count += 1
        if count >= max_count:
            break

# Save results to CSV
df = pd.DataFrame(results)
output_file = "filtered_100k_drug_like_molecules_updated.csv"
df.to_csv(output_file, index=False)

print(f"Filtered molecules saved to: {output_file}")
# Out:
# MCS SMILES: CCOC1:C:C2:N:C:N:C(NC3:C:C:C:C:C:3):C:2:C:C:1NC(C)=O
# Molecule 0: Lipinski False, CNS False, QED 0.2508287348406419
# Molecule 0: Lipinski False, CNS False, QED 0.25231273714008856
# Molecule 0: Lipinski False, CNS False, QED 0.2130544083536871
# Molecule 0: Lipinski False, CNS False, QED 0.20903044148285244
# Molecule 0: Lipinski False, CNS False, QED 0.2380016337858809
# Molecule 0: Lipinski False, CNS False, QED 0.2751429575501083
# Molecule 0: Lipinski False, CNS False, QED 0.2539599782879669
# Molecule 0: Lipinski False, CNS False, QED 0.2487330311459943
# Molecule 0: Lipinski False, CNS False, QED 0.2388335395886044
# Molecule 0: Lipinski False, CNS False, QED 0.2649989670685144
# Molecule 0: Lipinski False, CNS False, QED 0.17431621766701716
# Molecule 0: Lipinski False, CNS False, QED 0.24285483892209014
# Molecule 0: Lipinski True, CNS False, QED 0.4046798228156765
# Molecule 0: Lipinski False, CNS False, QED 0.24519514402023274
# Molecule 0: Lipinski False, CNS False, QED 0.20127064082158047
# Molecule 0: Lipinski False, CNS False, QED 0.23841854969954232
# Molecule 0: Lipinski False, CNS False, QED 0.29329820440919085
# Molecule 0: Lipinski False, CNS False, QED 0.20396342330986106
# Molecule 0: Lipinski False, CNS False, QED 0.23783079306990504
# Molecule 0: Lipinski False, CNS False, QED 0.13929323063382804
# Molecule 0: Lipinski False, CNS False, QED 0.2130544083536871
# Molecule 0: Lipinski False, CNS False, QED 0.3828331914652097
# Molecule 0: Lipinski False, CNS False, QED 0.16364753836291343
# Molecule 0: Lipinski False, CNS False, QED 0.1767629876453257
# Molecule 0: Lipinski False, CNS False, QED 0.2123863760741557
# Molecule 0: Lipinski False, CNS False, QED 0.18378639012532694
# Molecule 0: Lipinski False, CNS False, QED 0.22396663008959475
# Molecule 0: Lipinski True, CNS False, QED 0.3039201695183743
# Molecule 0: Lipinski False, CNS False, QED 0.2015818925797084
# Molecule 0: Lipinski False, CNS False, QED 0.18296832179860595
# Molecule 0: Lipinski False, CNS False, QED 0.15916508441639113
# Molecule 0: Lipinski False, CNS False, QED 0.24408419956766922
# Molecule 0: Lipinski False, CNS False, QED 0.24110650661935132
# Molecule 0: Lipinski False, CNS False, QED 0.17942410980022147
# Molecule 0: Lipinski True, CNS False, QED 0.2405120292012664
# Molecule 0: Lipinski False, CNS False, QED 0.15916508441639113
# Molecule 0: Lipinski False, CNS False, QED 0.3045584539985545
# Molecule 0: Lipinski False, CNS False, QED 0.18296832179860595
# Molecule 0: Lipinski False, CNS False, QED 0.20579037524065277
# Molecule 0: Lipinski False, CNS False, QED 0.16298820194188993
# Molecule 0: Lipinski False, CNS False, QED 0.17635177401617508
# Molecule 0: Lipinski True, CNS False, QED 0.3039201695183743
# Molecule 0: Lipinski False, CNS False, QED 0.22317539183317445
# Molecule 0: Lipinski False, CNS False, QED 0.12234722895073419
# Molecule 0: Lipinski False, CNS False, QED 0.2324075740250637
# Molecule 0: Lipinski False, CNS False, QED 0.16364753836291343
# Molecule 0: Lipinski False, CNS False, QED 0.1462504709269846
# Molecule 0: Lipinski False, CNS False, QED 0.17860269745559917
# Molecule 0: Lipinski False, CNS False, QED 0.169921277297751
# Molecule 0: Lipinski False, CNS False, QED 0.14465941708739136
# Molecule 0: Lipinski False, CNS False, QED 0.18857284812274802
# Molecule 0: Lipinski False, CNS False, QED 0.26210920045650155
# Molecule 0: Lipinski False, CNS False, QED 0.2528815227367063
# Molecule 0: Lipinski False, CNS False, QED 0.18039852808227053
# Molecule 0: Lipinski False, CNS False, QED 0.19868556411718233
# Molecule 0: Lipinski False, CNS False, QED 0.22896776987260822
# Molecule 0: Lipinski False, CNS False, QED 0.30630643122320095
# Molecule 0: Lipinski False, CNS False, QED 0.22367580394552083
# Molecule 0: Lipinski False, CNS False, QED 0.25513325490500444
# Molecule 0: Lipinski False, CNS False, QED 0.20994566279281895
# Molecule 0: Lipinski False, CNS False, QED 0.18378639012532694
# Molecule 0: Lipinski False, CNS False, QED 0.18857284812274802
# Molecule 0: Lipinski False, CNS False, QED 0.12694296626092968
# Molecule 0: Lipinski False, CNS False, QED 0.2064960011382801
# Molecule 0: Lipinski False, CNS False, QED 0.21519174270826663
# Molecule 0: Lipinski False, CNS False, QED 0.32384163044689757
# Molecule 0: Lipinski False, CNS False, QED 0.22582098278740786
# Molecule 0: Lipinski False, CNS False, QED 0.2123863760741557
# Molecule 0: Lipinski False, CNS False, QED 0.2323104926752142
# Molecule 0: Lipinski False, CNS False, QED 0.1722441319564276
# Molecule 0: Lipinski False, CNS False, QED 0.16747341976371122
# Molecule 0: Lipinski False, CNS False, QED 0.19401818419799088
# Molecule 0: Lipinski False, CNS False, QED 0.32384163044689757
# Molecule 0: Lipinski False, CNS False, QED 0.24557114917182932
# Molecule 0: Lipinski False, CNS False, QED 0.20314771098401282
# Molecule 0: Lipinski False, CNS False, QED 0.21826493138525133
# Molecule 0: Lipinski False, CNS False, QED 0.15251304885929884
# Molecule 0: Lipinski False, CNS False, QED 0.14591756383012214
# Molecule 0: Lipinski False, CNS False, QED 0.25023585434049633
# Molecule 0: Lipinski False, CNS False, QED 0.16559532477826583
# Molecule 0: Lipinski False, CNS False, QED 0.21814267742455726
# Molecule 0: Lipinski False, CNS False, QED 0.2596798179502244
# Molecule 0: Lipinski False, CNS False, QED 0.1981714740176725
# Molecule 0: Lipinski False, CNS False, QED 0.12694296626092968
# Molecule 0: Lipinski False, CNS False, QED 0.15865687716100926
# Molecule 0: Lipinski False, CNS False, QED 0.3662617760980409
# Molecule 0: Lipinski False, CNS False, QED 0.10055720443239088
# Molecule 0: Lipinski False, CNS False, QED 0.20904658214357252
# Molecule 0: Lipinski False, CNS False, QED 0.23027649985929183
# Molecule 0: Lipinski False, CNS False, QED 0.2839471796716191
# Molecule 0: Lipinski False, CNS False, QED 0.2324075740250637
# Molecule 0: Lipinski False, CNS False, QED 0.21491385202737615
# Molecule 0: Lipinski False, CNS False, QED 0.2215064443143418
# Molecule 0: Lipinski False, CNS False, QED 0.23756925490547723
# Molecule 0: Lipinski False, CNS False, QED 0.2380016337858809
# Molecule 0: Lipinski False, CNS False, QED 0.2692693629393266
# Molecule 0: Lipinski False, CNS False, QED 0.19868556411718233
# Molecule 0: Lipinski False, CNS False, QED 0.21111224833040915
# Molecule 0: Lipinski False, CNS False, QED 0.23250388050511903
# Molecule 0: Lipinski False, CNS False, QED 0.20834031589889432
# Molecule 0: Lipinski False, CNS False, QED 0.15214482902252457
# Molecule 0: Lipinski False, CNS False, QED 0.38497794835556015
# Molecule 0: Lipinski False, CNS False, QED 0.28894574556703856
# Molecule 0: Lipinski False, CNS False, QED 0.1418758669005389
# Molecule 0: Lipinski False, CNS False, QED 0.1712954876508025
# Molecule 0: Lipinski False, CNS False, QED 0.17161162357817966
# Molecule 0: Lipinski False, CNS False, QED 0.32384163044689757
# Molecule 0: Lipinski False, CNS False, QED 0.18058903534760273
# Molecule 0: Lipinski False, CNS False, QED 0.4061127656198028
# Molecule 0: Lipinski False, CNS False, QED 0.22530866756696644
# Molecule 0: Lipinski False, CNS False, QED 0.1895731851752738
# Molecule 0: Lipinski False, CNS False, QED 0.3553961541840084
# Molecule 0: Lipinski False, CNS False, QED 0.2289684867831902
# Molecule 0: Lipinski False, CNS False, QED 0.2138348968888548
# Molecule 0: Lipinski False, CNS False, QED 0.240298441721505
# Molecule 0: Lipinski False, CNS False, QED 0.32384163044689757
# Molecule 0: Lipinski False, CNS False, QED 0.27365683894444776
# Molecule 0: Lipinski False, CNS False, QED 0.25829113648050056
# Molecule 0: Lipinski False, CNS False, QED 0.2853354541118127
# Molecule 0: Lipinski False, CNS False, QED 0.22930344533891048
# Molecule 0: Lipinski False, CNS False, QED 0.19931551136361403
# Molecule 0: Lipinski False, CNS False, QED 0.2130544083536871
# Molecule 0: Lipinski False, CNS False, QED 0.1644016645588654
# Molecule 0: Lipinski False, CNS False, QED 0.26738242571729814
# Molecule 0: Lipinski False, CNS False, QED 0.10101299860141223
# Molecule 0: Lipinski False, CNS False, QED 0.20330989236639935
# Molecule 0: Lipinski False, CNS False, QED 0.1379501597374181
# Molecule 0: Lipinski False, CNS False, QED 0.2114355954748865
# Molecule 0: Lipinski False, CNS False, QED 0.19868556411718233
# Molecule 0: Lipinski False, CNS False, QED 0.28478695988795955
# Molecule 0: Lipinski False, CNS False, QED 0.19968215698069483
# Molecule 0: Lipinski False, CNS False, QED 0.30062396338527925
# Molecule 0: Lipinski False, CNS False, QED 0.25891458821541835
# Molecule 0: Lipinski False, CNS False, QED 0.13926419976935517
# Molecule 0: Lipinski False, CNS False, QED 0.24285483892209014
# Molecule 0: Lipinski False, CNS False, QED 0.23881246928181205
# Molecule 0: Lipinski False, CNS False, QED 0.21973445080702417
# Molecule 0: Lipinski False, CNS False, QED 0.33816752861935023
# Molecule 0: Lipinski False, CNS False, QED 0.13280297019632686
# Molecule 0: Lipinski False, CNS False, QED 0.25891458821541835
# Molecule 0: Lipinski False, CNS False, QED 0.10345776913665194
# Molecule 0: Lipinski False, CNS False, QED 0.2311615865924213
# Molecule 0: Lipinski False, CNS False, QED 0.2556590720044903
# Molecule 0: Lipinski False, CNS False, QED 0.20920331103948767
# Molecule 0: Lipinski False, CNS False, QED 0.15089147503758427
# Filtered molecules saved to: filtered_100k_drug_like_molecules_updated.csv

# %%
import random
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors, QED
import pandas as pd

# 常见的元素和基团库
element_choices = [
    (Chem.Atom(17), "Cl"),  # 氯
    (Chem.Atom(9), "F"),    # 氟
    (Chem.Atom(35), "Br"),  # 溴
    (Chem.Atom(53), "I"),   # 碘
    (Chem.Atom(6), "CH3"),  # 甲基（CH3）
    (Chem.Atom(7), "NH2"),  # 氨基
    (Chem.Atom(8), "OH"),   # 羟基
    (Chem.Atom(16), "SH"),  # 硫氢基（SH）
    (Chem.Atom(15), "PH"),  # 磷氢基（PH）
]

# 加载SDF文件
sdf_file = "molecule_set_largest_cluster.sdf"
supplier = Chem.SDMolSupplier(sdf_file)

# 过滤有效的分子
molecules = [mol for mol in supplier if mol is not None]

# 函数：添加随机元素或基团
def add_random_element(editable_mol):
    atom, label = random.choice(element_choices)
    editable_mol.AddAtom(atom)  # 添加随机选择的原子
    print(f"Added element: {label}")

# 初始化结果和计数器
results = []
count = 0
max_count = 100000

# 对每个分子进行处理
for mol in molecules:
    # 创建分子副本进行编辑
    mol_copy = Chem.Mol(mol)
    editable_mol = Chem.EditableMol(mol_copy)

    # 添加两个随机元素或基团
    add_random_element(editable_mol)
    add_random_element(editable_mol)
    
    # 完成分子并计算性质
    optimized_mol = editable_mol.GetMol()
    AllChem.Compute2DCoords(optimized_mol)
    AllChem.AddHs(optimized_mol)

    # 计算QED分数
    qed_score = QED.qed(optimized_mol)
    
    # 检查是否符合Lipinski和CNS规则
    lipinski_pass = lipinski_rule_of_five(optimized_mol)
    cns_pass = cns_drug_likeness(optimized_mol)

    # 打印每个步骤日志
    print(f"Molecule {count}: Lipinski {lipinski_pass}, CNS {cns_pass}, QED {qed_score}")

    # 保存符合条件的分子
    if lipinski_pass and cns_pass and qed_score > 0.7:
        logp, hbd, hba, num_aromatic_rings, num_aliphatic_rings, non_c_ratio = calculate_additional_properties(optimized_mol)
        results.append({
            'id': count,
            'smiles': Chem.MolToSmiles(optimized_mol),
            'QED': qed_score,
            'Lipinski': lipinski_pass,
            'CNS': cns_pass,
            'LogP': logp,
            'HBD': hbd,
            'HBA': hba,
            'Aromatic Rings': num_aromatic_rings,
            'Aliphatic Rings': num_aliphatic_rings,
            'Non-C Ratio': non_c_ratio
        })
        count += 1
        if count >= max_count:
            break

# 保存结果为CSV文件
df = pd.DataFrame(results)
output_file = "filtered_100k_drug_like_molecules_with_random_elements.csv"
df.to_csv(output_file, index=False)

print(f"Filtered molecules saved to: {output_file}")
# Out:
# Added element: I
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.1727812908506852
# Added element: F
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.2689686171720111
# Added element: OH
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.19756566947289975
# Added element: F
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.2216729918379981
# Added element: OH
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.2464146252753658
# Added element: NH2
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.16036876066066946
# Added element: OH
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.29453678728702787
# Added element: OH
# Added element: PH
# Molecule 0: Lipinski False, CNS False, QED 0.217289307787076
# Added element: SH
# Added element: Cl
# Molecule 0: Lipinski False, CNS False, QED 0.2428204973211695
# Added element: I
# Added element: Cl
# Molecule 0: Lipinski False, CNS False, QED 0.17839348422037538
# Added element: I
# Added element: Br
# Molecule 0: Lipinski False, CNS False, QED 0.10799219717332456
# Added element: SH
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.25351762135813666
# Added element: NH2
# Added element: CH3
# Molecule 0: Lipinski True, CNS False, QED 0.36540468718797536
# Added element: PH
# Added element: F
# Molecule 0: Lipinski False, CNS False, QED 0.1950008998196859
# Added element: OH
# Added element: Cl
# Molecule 0: Lipinski False, CNS False, QED 0.22731958535551813
# Added element: Cl
# Added element: F
# Molecule 0: Lipinski False, CNS False, QED 0.19201260495905292
# Added element: CH3
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.29083912401059697
# Added element: Br
# Added element: PH
# Molecule 0: Lipinski False, CNS False, QED 0.15640431314401856
# Added element: NH2
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.21999586163438056
# Added element: I
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.11173123817473957
# Added element: Cl
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.2130544083536871
# Added element: CH3
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.4426227956769831
# Added element: F
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.17571043989427484
# Added element: NH2
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.16705087998144885
# Added element: I
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.12835273362885616
# Added element: Br
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.1946825533559317
# Added element: OH
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.22525717323514013
# Added element: Br
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.2737200603509387
# Added element: SH
# Added element: Cl
# Molecule 0: Lipinski False, CNS False, QED 0.20589034767688408
# Added element: I
# Added element: PH
# Molecule 0: Lipinski False, CNS False, QED 0.09862048354587043
# Added element: PH
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.11444795331038947
# Added element: PH
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.1676917470048141
# Added element: OH
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.25305632910197784
# Added element: PH
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.1641178554896811
# Added element: I
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.15389552506290527
# Added element: PH
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.11444795331038947
# Added element: CH3
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.27557254944647946
# Added element: PH
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.14718196024685082
# Added element: PH
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.11438627457468542
# Added element: PH
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.12917189395774886
# Added element: NH2
# Added element: PH
# Molecule 0: Lipinski False, CNS False, QED 0.1191390135339331
# Added element: F
# Added element: Br
# Molecule 0: Lipinski False, CNS False, QED 0.2841774397088243
# Added element: F
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.23253776903783058
# Added element: F
# Added element: Cl
# Molecule 0: Lipinski False, CNS False, QED 0.1306366306345577
# Added element: SH
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.24329734778973539
# Added element: OH
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.18228666717440647
# Added element: OH
# Added element: PH
# Molecule 0: Lipinski False, CNS False, QED 0.12472678553739412
# Added element: PH
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.09379802232958266
# Added element: F
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.18950668814014943
# Added element: OH
# Added element: Br
# Molecule 0: Lipinski False, CNS False, QED 0.15701314537223443
# Added element: SH
# Added element: PH
# Molecule 0: Lipinski False, CNS False, QED 0.15524818722360148
# Added element: OH
# Added element: Cl
# Molecule 0: Lipinski False, CNS False, QED 0.28414835302446384
# Added element: PH
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.22296295726188453
# Added element: NH2
# Added element: Cl
# Molecule 0: Lipinski False, CNS False, QED 0.16247222374565803
# Added element: OH
# Added element: PH
# Molecule 0: Lipinski False, CNS False, QED 0.17602331641452193
# Added element: I
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.13892537721395565
# Added element: F
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.3283541320950298
# Added element: I
# Added element: Br
# Molecule 0: Lipinski False, CNS False, QED 0.15656590455246025
# Added element: OH
# Added element: Cl
# Molecule 0: Lipinski False, CNS False, QED 0.2605206513285201
# Added element: Br
# Added element: Cl
# Molecule 0: Lipinski False, CNS False, QED 0.1933278721804183
# Added element: OH
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.215962791448785
# Added element: Br
# Added element: Cl
# Molecule 0: Lipinski False, CNS False, QED 0.17810428115397506
# Added element: NH2
# Added element: PH
# Molecule 0: Lipinski False, CNS False, QED 0.09222304531815204
# Added element: CH3
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.1375800570663013
# Added element: PH
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.2043028371066908
# Added element: CH3
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.21900438293884833
# Added element: I
# Added element: F
# Molecule 0: Lipinski False, CNS False, QED 0.163674396636828
# Added element: Br
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.17635212028441352
# Added element: F
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.23500078283446013
# Added element: Br
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.14237636244199064
# Added element: Br
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.15810855450025388
# Added element: OH
# Added element: Cl
# Molecule 0: Lipinski False, CNS False, QED 0.21960724441451743
# Added element: Br
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.3079618701354602
# Added element: PH
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.19655728057817812
# Added element: CH3
# Added element: Br
# Molecule 0: Lipinski False, CNS False, QED 0.18665412582978722
# Added element: NH2
# Added element: Br
# Molecule 0: Lipinski False, CNS False, QED 0.1810653425883713
# Added element: Cl
# Added element: F
# Molecule 0: Lipinski False, CNS False, QED 0.16071378716565923
# Added element: I
# Added element: Br
# Molecule 0: Lipinski False, CNS False, QED 0.09787646552743585
# Added element: I
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.15562800086720907
# Added element: NH2
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.13279270674508817
# Added element: PH
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.1822814387639847
# Added element: OH
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.32553431506389574
# Added element: F
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.20563126234700904
# Added element: Br
# Added element: F
# Molecule 0: Lipinski False, CNS False, QED 0.12842091258578492
# Added element: F
# Added element: Br
# Molecule 0: Lipinski False, CNS False, QED 0.1579233248049647
# Added element: I
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.2333166455933524
# Added element: OH
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.11985894627059747
# Added element: PH
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.16413264682141634
# Added element: PH
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.127904662452128
# Added element: CH3
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.19385136199085012
# Added element: PH
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.19302712582119816
# Added element: PH
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.1717664960094487
# Added element: CH3
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.19834318432405484
# Added element: I
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.17672439740042986
# Added element: F
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.2520963753962252
# Added element: SH
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.1797151902855024
# Added element: NH2
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.12581209046172673
# Added element: CH3
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.2150982423467438
# Added element: CH3
# Added element: F
# Molecule 0: Lipinski False, CNS False, QED 0.24129888248104125
# Added element: NH2
# Added element: Cl
# Molecule 0: Lipinski False, CNS False, QED 0.19645219231623032
# Added element: NH2
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.14723662707021568
# Added element: I
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.2494276441369632
# Added element: NH2
# Added element: NH2
# Molecule 0: Lipinski True, CNS False, QED 0.22878079767416434
# Added element: CH3
# Added element: F
# Molecule 0: Lipinski False, CNS False, QED 0.14783434093397796
# Added element: OH
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.20356558192972438
# Added element: F
# Added element: PH
# Molecule 0: Lipinski False, CNS False, QED 0.13859354700670923
# Added element: SH
# Added element: PH
# Molecule 0: Lipinski False, CNS False, QED 0.272811567712296
# Added element: Br
# Added element: PH
# Molecule 0: Lipinski False, CNS False, QED 0.12769196231401675
# Added element: NH2
# Added element: Br
# Molecule 0: Lipinski False, CNS False, QED 0.3434725444905442
# Added element: CH3
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.24611985534443087
# Added element: SH
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.13456061631978458
# Added element: SH
# Added element: F
# Molecule 0: Lipinski False, CNS False, QED 0.3951526638287917
# Added element: Cl
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.15476956578753404
# Added element: Cl
# Added element: Br
# Molecule 0: Lipinski False, CNS False, QED 0.1959899534551128
# Added element: NH2
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.1914549579192176
# Added element: PH
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.272811567712296
# Added element: Cl
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.17661652324889565
# Added element: I
# Added element: PH
# Molecule 0: Lipinski False, CNS False, QED 0.13699473953164473
# Added element: OH
# Added element: Cl
# Molecule 0: Lipinski False, CNS False, QED 0.3033876329458447
# Added element: SH
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.23995148285985085
# Added element: NH2
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.15633672905536852
# Added element: Cl
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.187501738225907
# Added element: OH
# Added element: Br
# Molecule 0: Lipinski False, CNS False, QED 0.1710427339815667
# Added element: PH
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.2259884044071234
# Added element: CH3
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.07105269006771782
# Added element: SH
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.21100436078381393
# Added element: PH
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.09243178938284047
# Added element: CH3
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.14313247957157577
# Added element: Br
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.18656777542923422
# Added element: I
# Added element: F
# Molecule 0: Lipinski False, CNS False, QED 0.1945742605627331
# Added element: SH
# Added element: Br
# Molecule 0: Lipinski False, CNS False, QED 0.19584126789770717
# Added element: OH
# Added element: OH
# Molecule 0: Lipinski False, CNS False, QED 0.33072396498571033
# Added element: I
# Added element: I
# Molecule 0: Lipinski False, CNS False, QED 0.15873092156745094
# Added element: Cl
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.12495968250734701
# Added element: OH
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.23829870537839756
# Added element: PH
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.17402942952071696
# Added element: PH
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.1474603562449503
# Added element: F
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.3599593510343806
# Added element: OH
# Added element: NH2
# Molecule 0: Lipinski False, CNS False, QED 0.1370101181563309
# Added element: SH
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.2643177140361549
# Added element: I
# Added element: CH3
# Molecule 0: Lipinski False, CNS False, QED 0.07190015812501997
# Added element: I
# Added element: Br
# Molecule 0: Lipinski False, CNS False, QED 0.15542017400814845
# Added element: F
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.27753159299950864
# Added element: Cl
# Added element: SH
# Molecule 0: Lipinski False, CNS False, QED 0.21134030326192904
# Added element: Br
# Added element: F
# Molecule 0: Lipinski False, CNS False, QED 0.14541820598155547
# Filtered molecules saved to: filtered_100k_drug_like_molecules_with_random_elements.csv

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors, QED
import torch
import torch.nn as nn
from torch_geometric.data import Data
from sklearn.model_selection import train_test_split

# 读取EGFR compounds数据
egfr_csv_file = "EGFR_compounds_lipinski_noPAINS_noBrenk.csv"
egfr_df = pd.read_csv(egfr_csv_file)

# 根据pIC50值划分数据集（假设pIC50列名为"pIC50"）
high_activity_df = egfr_df[egfr_df["pIC50"] >= 8]  # 活性较好的数据（pIC50 >= 8）
low_activity_df = egfr_df[egfr_df["pIC50"] < 8]    # 活性较低的数据

# 加载SDF文件
sdf_file = "molecule_set_largest_cluster.sdf"
supplier = Chem.SDMolSupplier(sdf_file)

# 过滤有效分子
molecules = [mol for mol in supplier if mol is not None]

# 构建GCN模型
class GCN(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GCN, self).__init__()
        self.conv1 = nn.Linear(input_dim, hidden_dim)
        self.conv2 = nn.Linear(hidden_dim, output_dim)
        self.fc = nn.Linear(output_dim, 1)

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = torch.relu(self.conv2(x))
        x = torch.mean(x, dim=0)
        return self.fc(x)

# 将SMILES转换为分子图
def smiles_to_graph(smiles):
    mol = Chem.MolFromSmiles(smiles)
    atoms = [atom.GetAtomicNum() for atom in mol.GetAtoms()]
    bonds = []
    for bond in mol.GetBonds():
        bonds.append((bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()))
    data = Data(x=torch.tensor(atoms, dtype=torch.float).view(-1, 1),
                edge_index=torch.tensor(bonds, dtype=torch.long).t().contiguous())
    return data

# 将EGFR数据集转换为图表示
high_activity_smiles = high_activity_df["smiles"].values
low_activity_smiles = low_activity_df["smiles"].values
high_activity_data_list = [smiles_to_graph(smiles) for smiles in high_activity_smiles]
low_activity_data_list = [smiles_to_graph(smiles) for smiles in low_activity_smiles]

# 按pIC50分为训练集和测试集
train_data, test_data = train_test_split(high_activity_data_list, test_size=0.2, random_state=42)

# 使用GCN模型预测并优化分子
def optimize_molecule(mol, model):
    mol_data = smiles_to_graph(Chem.MolToSmiles(mol))
    return model(mol_data.x)

# 创建GCN模型实例
input_dim = 1
hidden_dim = 32
output_dim = 16
model = GCN(input_dim, hidden_dim, output_dim)

# 训练模型
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
loss_fn = nn.MSELoss()

for epoch in range(100):
    model.train()
    total_loss = 0
    for data in train_data:
        optimizer.zero_grad()
        output = model(data.x)
        target = torch.tensor([Descriptors.MolWt(Chem.MolFromSmiles('CCO'))], dtype=torch.float)
        loss = loss_fn(output, target)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f'Epoch {epoch}, Loss: {total_loss}')

# 优化并生成新分子
optimized_results = []
for mol in molecules:
    optimized_score = optimize_molecule(mol, model)
    smiles = Chem.MolToSmiles(mol)
    qed_score = QED.qed(mol)
    if qed_score > 0.5:  # 只保留QED大于0.7的分子
        optimized_results.append({
            "smiles": smiles,
            "optimized_score": optimized_score.item(),
            "QED": qed_score
        })

# 保存优化后的分子为CSV文件
df = pd.DataFrame(optimized_results)
output_file = "optimized_drug_like_molecules.csv"
df.to_csv(output_file, index=False)

print(f"Optimized molecules saved to: {output_file}")
# Out:
# Epoch 0, Loss: 36755.35322060525
# Epoch 1, Loss: 2784.254277016502
# Epoch 2, Loss: 2670.54922376413
# Epoch 3, Loss: 2515.8356804414652
# Epoch 4, Loss: 2346.6379591668374
# Epoch 5, Loss: 2167.320482035051
# Epoch 6, Loss: 1978.3645905772137
# Epoch 7, Loss: 1778.7025899024447
# Epoch 8, Loss: 1566.6522970463848
# Epoch 9, Loss: 1347.5483860050008
# Epoch 10, Loss: 1122.337716943468
# Epoch 11, Loss: 917.2711724587134
# Epoch 12, Loss: 685.5865127347206
# Epoch 13, Loss: 493.48083153396146
# Epoch 14, Loss: 332.7167346635979
# Epoch 15, Loss: 214.93820264813257
# Epoch 16, Loss: 124.28177051326202
# Epoch 17, Loss: 61.55685647108476
# Epoch 18, Loss: 23.917921364627546
# Epoch 19, Loss: 7.071251437577303
# Epoch 20, Loss: 1.6458271469309693
# Epoch 21, Loss: 0.2495762168400688
# Epoch 22, Loss: 0.0261760383436922
# Epoch 23, Loss: 0.0016904692893149331
# Epoch 24, Loss: 5.1553884986788034e-05
# Epoch 25, Loss: 1.7226120689883828e-06
# Epoch 26, Loss: 4.480534698814154e-08
# Epoch 27, Loss: 9.880750440061092e-09
# Epoch 28, Loss: 9.022187441587448e-09
# Epoch 29, Loss: 2.2220774553716183e-08
# Epoch 30, Loss: 1.7316779121756554e-08
# Epoch 31, Loss: 2.0358129404485226e-08
# Epoch 32, Loss: 6.622576620429754e-08
# Epoch 33, Loss: 1.8671562429517508e-07
# Epoch 34, Loss: 1.549633452668786e-07
# Epoch 35, Loss: 1.60778290592134e-06
# Epoch 36, Loss: 0.0004985435516573489
# Epoch 37, Loss: 21.784479093941627
# Epoch 38, Loss: 1.3946656258049188
# Epoch 39, Loss: 0.12216946980333887
# Epoch 40, Loss: 0.014074922204599716
# Epoch 41, Loss: 0.28724650490039494
# Epoch 42, Loss: 2.548372056320659
# Epoch 43, Loss: 19.176212350910646
# Epoch 44, Loss: 0.0030909762281225994
# Epoch 45, Loss: 0.018162726162699983
# Epoch 46, Loss: 1.6593033783283317
# Epoch 47, Loss: 10.018865773658035
# Epoch 48, Loss: 1.0092211663286434
# Epoch 49, Loss: 0.2610834104998503
# Epoch 50, Loss: 9.816480645677075
# Epoch 51, Loss: 0.5148042076907586
# Epoch 52, Loss: 0.04963682606467046
# Epoch 53, Loss: 5.843186774334754
# Epoch 54, Loss: 11.701058193750214
# Epoch 55, Loss: 0.21073181698739063
# Epoch 56, Loss: 0.690523148063221
# Epoch 57, Loss: 2.4297844562970567
# Epoch 58, Loss: 5.32437427896366
# Epoch 59, Loss: 1.4219152478326578
# Epoch 60, Loss: 4.121357340540271
# Epoch 61, Loss: 11.385751856927527
# Epoch 62, Loss: 1.0432602637738455
# Epoch 63, Loss: 0.2578287304204423
# Epoch 64, Loss: 0.2897109004261438
# Epoch 65, Loss: 0.039500312152085826
# Epoch 66, Loss: 1.8871581962885102
# Epoch 67, Loss: 9.327564119550516
# Epoch 68, Loss: 3.0602672526438255
# Epoch 69, Loss: 0.7422036338102771
# Epoch 70, Loss: 7.747299339709571
# Epoch 71, Loss: 4.305834441882325
# Epoch 72, Loss: 0.16302330377220642
# Epoch 73, Loss: 0.0016100687498692423
# Epoch 74, Loss: 0.005778496648417786
# Epoch 75, Loss: 12.991066688395222
# Epoch 76, Loss: 0.881626582777244
# Epoch 77, Loss: 0.10234704757749569
# Epoch 78, Loss: 0.8498030692862812
# Epoch 79, Loss: 0.286819920031121
# Epoch 80, Loss: 1.013878104655305
# Epoch 81, Loss: 7.503435656064539
# Epoch 82, Loss: 3.9616075255471515
# Epoch 83, Loss: 1.4536733647546498
# Epoch 84, Loss: 1.026383147967863
# Epoch 85, Loss: 10.798740562691819
# Epoch 86, Loss: 0.3711380681779701
# Epoch 87, Loss: 0.4966033567179693
# Epoch 88, Loss: 0.9954125044314424
# Epoch 89, Loss: 8.214994678157382
# Epoch 90, Loss: 0.8330915983970044
# Epoch 91, Loss: 0.21156667756440584
# Epoch 92, Loss: 0.41443169057311025
# Epoch 93, Loss: 1.4366422305174638
# Epoch 94, Loss: 9.911900026956573
# Epoch 95, Loss: 3.712822939924081
# Epoch 96, Loss: 0.7284566386806546
# Epoch 97, Loss: 1.107650091405958
# Epoch 98, Loss: 1.0095109672402032
# Epoch 99, Loss: 2.5200235835800413
# Optimized molecules saved to: optimized_drug_like_molecules.csv

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors, QED
import torch
import torch.nn as nn
from torch_geometric.data import Data
from sklearn.model_selection import train_test_split

# 读取EGFR compounds数据
egfr_csv_file = "EGFR_compounds_lipinski_noPAINS_noBrenk.csv"
egfr_df = pd.read_csv(egfr_csv_file)

# 根据pIC50值划分数据集（假设pIC50列名为"pIC50"）
high_activity_df = egfr_df[egfr_df["pIC50"] >= 8]  # 活性较好的数据（pIC50 >= 8）
low_activity_df = egfr_df[egfr_df["pIC50"] < 8]    # 活性较低的数据

# 加载SDF文件
sdf_file = "molecule_set_largest_cluster.sdf"
supplier = Chem.SDMolSupplier(sdf_file)

# 过滤有效分子
molecules = [mol for mol in supplier if mol is not None]

# 构建GCN模型
class GCN(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GCN, self).__init__()
        self.conv1 = nn.Linear(input_dim, hidden_dim)
        self.conv2 = nn.Linear(hidden_dim, output_dim)
        self.fc = nn.Linear(output_dim, 1)

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = torch.relu(self.conv2(x))
        x = torch.mean(x, dim=0)
        return self.fc(x)

# 将SMILES转换为分子图
def smiles_to_graph(smiles):
    mol = Chem.MolFromSmiles(smiles)
    atoms = [atom.GetAtomicNum() for atom in mol.GetAtoms()]
    bonds = []
    for bond in mol.GetBonds():
        bonds.append((bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()))
    data = Data(x=torch.tensor(atoms, dtype=torch.float).view(-1, 1),
                edge_index=torch.tensor(bonds, dtype=torch.long).t().contiguous())
    return data

# 将数据集转换为图表示
high_activity_smiles = high_activity_df["smiles"].values
high_activity_data_list = [smiles_to_graph(smiles) for smiles in high_activity_smiles]

# 训练集和测试集划分
train_data, test_data = train_test_split(high_activity_data_list, test_size=0.2, random_state=2)

# 使用GCN模型预测并优化分子
def optimize_molecule(mol, model):
    mol_data = smiles_to_graph(Chem.MolToSmiles(mol))
    return model(mol_data.x)

# 创建GCN模型实例
input_dim = 1
hidden_dim = 32
output_dim = 16
model = GCN(input_dim, hidden_dim, output_dim)

# 训练模型
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
loss_fn = nn.MSELoss()

for epoch in range(100):
    model.train()
    total_loss = 0
    for data in train_data:
        optimizer.zero_grad()
        output = model(data.x)
        # 这里的目标值可以根据EGFR活性数据进行修改
        target = torch.tensor([1.0], dtype=torch.float)  # 示例目标
        loss = loss_fn(output, target)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f'Epoch {epoch}, Loss: {total_loss}')

# 评估分子是否符合Lipinski's Rule of Five
def lipinski_rule_of_five(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)
    
    # Lipinski's Rule of Five
    return mol_weight <= 500 and logp <= 5 and hbd <= 5 and hba <= 10

# 评估分子是否符合CNS药物设计规则
def cns_drug_likeness(mol):
    mol_weight = Descriptors.MolWt(mol)
    logp = Descriptors.MolLogP(mol)
    tpsa = Descriptors.TPSA(mol)
    
    # CNS药物规则：分子量小于400，logP在2到3之间，TPSA小于90
    return mol_weight <= 400 and 2 <= logp <= 3 and tpsa <= 90

# 计算分子的额外属性
def calculate_additional_properties(mol):
    logp = Descriptors.MolLogP(mol)
    hbd = Descriptors.NumHDonors(mol)
    hba = Descriptors.NumHAcceptors(mol)
    num_aromatic_rings = Chem.rdMolDescriptors.CalcNumAromaticRings(mol)
    num_aliphatic_rings = Chem.rdMolDescriptors.CalcNumAliphaticRings(mol)
    num_non_h_atoms = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() > 1)
    num_non_c_atoms = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() != 6)
    non_c_ratio = num_non_c_atoms / num_non_h_atoms if num_non_h_atoms > 0 else 0
    return logp, hbd, hba, num_aromatic_rings, num_aliphatic_rings, non_c_ratio

# 优化并生成新分子
optimized_results = []
for mol in molecules:
    optimized_score = optimize_molecule(mol, model)
    smiles = Chem.MolToSmiles(mol)
    qed_score = QED.qed(mol)
    
    # 评估分子是否符合药物设计规则
    lipinski_pass = lipinski_rule_of_five(mol)
    cns_pass = cns_drug_likeness(mol)
    logp, hbd, hba, num_aromatic_rings, num_aliphatic_rings, non_c_ratio = calculate_additional_properties(mol)

    # 只保留符合所有规则且QED大于0.7的分子
    if qed_score > 0.7 and lipinski_pass and cns_pass:
        optimized_results.append({
            "smiles": smiles,
            "optimized_score": optimized_score.item(),
            "QED": qed_score,
            "Lipinski": lipinski_pass,
            "CNS": cns_pass,
            "LogP": logp,
            "HBD": hbd,
            "HBA": hba,
            "Aromatic Rings": num_aromatic_rings,
            "Aliphatic Rings": num_aliphatic_rings,
            "Non-C Ratio": non_c_ratio
        })

# 保存优化后的分子为CSV文件
df = pd.DataFrame(optimized_results)
output_file = "optimized_drug_like_molecules_with_properties.csv"
df.to_csv(output_file, index=False)

print(f"Optimized molecules saved to: {output_file}")
# Out:
# Epoch 0, Loss: 3.820669558181308
# Epoch 1, Loss: 0.15938795288310814
# Epoch 2, Loss: 0.001077499355258027
# Epoch 3, Loss: 6.264048799309307e-05
# Epoch 4, Loss: 6.065685270328913e-05
# Epoch 5, Loss: 1.9606471770572398e-05
# Epoch 6, Loss: 1.1328380328023968e-05
# Epoch 7, Loss: 1.4471897582524207e-05
# Epoch 8, Loss: 8.171737594153683e-06
# Epoch 9, Loss: 4.823461222969172e-05
# Epoch 10, Loss: 0.026289895486616643
# Epoch 11, Loss: 0.12788284045204534
# Epoch 12, Loss: 0.04200148868119413
# Epoch 13, Loss: 0.004117860125507633
# Epoch 14, Loss: 0.001073681488556133
# Epoch 15, Loss: 0.0024058764258612086
# Epoch 16, Loss: 0.00041380684676184387
# Epoch 17, Loss: 0.0003224942307760159
# Epoch 18, Loss: 0.005351376177056721
# Epoch 19, Loss: 0.0171978619811739
# Epoch 20, Loss: 0.050753731544489256
# Epoch 21, Loss: 0.014226661852173805
# Epoch 22, Loss: 0.12406663464784629
# Epoch 23, Loss: 0.011260406475834372
# Epoch 24, Loss: 0.0033463208166395475
# Epoch 25, Loss: 0.0016930565857649071
# Epoch 26, Loss: 0.001023851328515235
# Epoch 27, Loss: 0.0018600689964145545
# Epoch 28, Loss: 0.0013251768371667083
# Epoch 29, Loss: 0.0006892445658159829
# Epoch 30, Loss: 0.004258367367075522
# Epoch 31, Loss: 0.01387439585207062
# Epoch 32, Loss: 0.011004670457040788
# Epoch 33, Loss: 0.003785685899419633
# Epoch 34, Loss: 0.0019566039268497093
# Epoch 35, Loss: 0.00019717551618469997
# Epoch 36, Loss: 0.0005921027749131724
# Epoch 37, Loss: 0.0004237589126816488
# Epoch 38, Loss: 0.0003454152600781413
# Epoch 39, Loss: 0.001398880168046901
# Epoch 40, Loss: 0.0022182646451582855
# Epoch 41, Loss: 0.0009781450501051836
# Epoch 42, Loss: 0.0016214567886585485
# Epoch 43, Loss: 0.058013840805049455
# Epoch 44, Loss: 0.004847780175619931
# Epoch 45, Loss: 0.0033386280437355254
# Epoch 46, Loss: 0.0024843123900026853
# Epoch 47, Loss: 0.0018483545032594861
# Epoch 48, Loss: 0.0013715886666751942
# Epoch 49, Loss: 0.0010819438703322248
# Epoch 50, Loss: 0.0009032114261025015
# Epoch 51, Loss: 0.0007752437558430358
# Epoch 52, Loss: 0.0006409533893219077
# Epoch 53, Loss: 0.0005463193129280342
# Epoch 54, Loss: 0.00047146017555377284
# Epoch 55, Loss: 0.0004003943819590461
# Epoch 56, Loss: 0.00036739417737763347
# Epoch 57, Loss: 0.00026419870442140336
# Epoch 58, Loss: 0.0001785764059754058
# Epoch 59, Loss: 0.00015018622866591613
# Epoch 60, Loss: 0.0001452266587236295
# Epoch 61, Loss: 9.902863996913425e-05
# Epoch 62, Loss: 4.586947534335195e-05
# Epoch 63, Loss: 0.00014381087324011332
# Epoch 64, Loss: 5.178637809422071e-05
# Epoch 65, Loss: 0.00010298168860956025
# Epoch 66, Loss: 4.9759790925918423e-05
# Epoch 67, Loss: 6.0233125712017e-05
# Epoch 68, Loss: 1.3142119144049502e-05
# Epoch 69, Loss: 1.5923113561910895e-05
# Epoch 70, Loss: 1.4671708722602261e-05
# Epoch 71, Loss: 0.00015488956442766266
# Epoch 72, Loss: 5.4583358846116425e-05
# Epoch 73, Loss: 1.8815203134181502e-05
# Epoch 74, Loss: 1.2479339353888008e-05
# Epoch 75, Loss: 5.019453439558674e-06
# Epoch 76, Loss: 2.845536222650935e-06
# Epoch 77, Loss: 1.897614922086177e-06
# Epoch 78, Loss: 2.4412426213871186e-07
# Epoch 79, Loss: 2.1708214514859492e-05
# Epoch 80, Loss: 1.1727372910996792e-05
# Epoch 81, Loss: 1.7153875816688924e-05
# Epoch 82, Loss: 1.9609259062747242e-05
# Epoch 83, Loss: 1.8738209348612145e-05
# Epoch 84, Loss: 2.0151165145421146e-05
# Epoch 85, Loss: 2.1067323771717383e-05
# Epoch 86, Loss: 1.4605973337467049e-05
# Epoch 87, Loss: 2.652069712283378e-05
# Epoch 88, Loss: 1.5246331528828705e-05
# Epoch 89, Loss: 1.6947369562814174e-05
# Epoch 90, Loss: 1.543907610468409e-05
# Epoch 91, Loss: 3.0093112243889664e-05
# Epoch 92, Loss: 1.5376004437683832e-05
# Epoch 93, Loss: 1.8338669914186312e-05
# Epoch 94, Loss: 2.2071560504599574e-05
# Epoch 95, Loss: 7.062794793455396e-12
# Epoch 96, Loss: 0.0
# Epoch 97, Loss: 0.0
# Epoch 98, Loss: 0.0
# Epoch 99, Loss: 0.0
# Optimized molecules saved to: optimized_drug_like_molecules_with_properties.csv
